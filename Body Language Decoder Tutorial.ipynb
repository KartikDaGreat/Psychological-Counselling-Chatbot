# %% [markdown]
# # 0. Install and Import Dependencies

# %%
import mediapipe # Import mediapipe
import cv2 # Import opencv
# Out:
# WARNING:tensorflow:From c:\Users\Kartik Gounder\Desktop\Projects\.venv\Lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.

# %%
mp_drawing = mediapipe.solutions.drawing_utils # Drawing helpers
mp_holistic = mediapipe.solutions.holistic # Mediapipe Solutions

# %% [markdown]
# # 1. Make Some Detections

# %%
cap = cv2.VideoCapture(2)
# Initiate holistic model
with mp_holistic.Holistic(min_detection_confidence=0.5, min_tracking_confidence=0.5) as holistic:
    
    while cap.isOpened():
        ret, frame = cap.read()
        
        # Recolor Feed
        image = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
        image.flags.writeable = False        
        
        # Make Detections
        results = holistic.process(image)
        # print(results.face_landmarks)
        
        # face_landmarks, pose_landmarks, left_hand_landmarks, right_hand_landmarks
        
        # Recolor image back to BGR for rendering
        image.flags.writeable = True   
        image = cv2.cvtColor(image, cv2.COLOR_RGB2BGR)
        
        # 1. Draw face landmarks
        mp_drawing.draw_landmarks(image, results.face_landmarks, mp_holistic.FACEMESH_TESSELATION, 
                                 mp_drawing.DrawingSpec(color=(80,110,10), thickness=1, circle_radius=1),
                                 mp_drawing.DrawingSpec(color=(80,256,121), thickness=1, circle_radius=1)
                                 )
        
        # 2. Right hand
        mp_drawing.draw_landmarks(image, results.right_hand_landmarks, mp_holistic.HAND_CONNECTIONS, 
                                 mp_drawing.DrawingSpec(color=(80,22,10), thickness=2, circle_radius=4),
                                 mp_drawing.DrawingSpec(color=(80,44,121), thickness=2, circle_radius=2)
                                 )

        # 3. Left Hand
        mp_drawing.draw_landmarks(image, results.left_hand_landmarks, mp_holistic.HAND_CONNECTIONS, 
                                 mp_drawing.DrawingSpec(color=(121,22,76), thickness=2, circle_radius=4),
                                 mp_drawing.DrawingSpec(color=(121,44,250), thickness=2, circle_radius=2)
                                 )

        # 4. Pose Detections
        mp_drawing.draw_landmarks(image, results.pose_landmarks, mp_holistic.POSE_CONNECTIONS, 
                                 mp_drawing.DrawingSpec(color=(245,117,66), thickness=2, circle_radius=4),
                                 mp_drawing.DrawingSpec(color=(245,66,230), thickness=2, circle_radius=2)
                                 )
                        
        cv2.imshow('Raw Webcam Feed', image)

        if cv2.waitKey(10) & 0xFF == ord('q'):
            break

cap.release()
cv2.destroyAllWindows()

# %%
results.face_landmarks.landmark[0].visibility
# Out:
# 0.0

# %% [markdown]
# # 2. Capture Landmarks & Export to CSV
# <!--<img src="https://i.imgur.com/8bForKY.png">-->
# <!--<img src="https://i.imgur.com/AzKNp7A.png">-->

# %%
import csv
import os
import numpy as np
import time

# %%
num_coords = len(results.pose_landmarks.landmark)+len(results.face_landmarks.landmark)
num_coords
# Out:
# 501

# %%
landmarks = ['class_intensity']
for val in range(1, num_coords+1):
    landmarks += ['x{}'.format(val), 'y{}'.format(val), 'z{}'.format(val), 'v{}'.format(val)]

# %%
landmarks
# Out:
# ['class_intensity',
#  'x1',
#  'y1',
#  'z1',
#  'v1',
#  'x2',
#  'y2',
#  'z2',
#  'v2',
#  'x3',
#  'y3',
#  'z3',
#  'v3',
#  'x4',
#  'y4',
#  'z4',
#  'v4',
#  'x5',
#  'y5',
#  'z5',
#  'v5',
#  'x6',
#  'y6',
#  'z6',
#  'v6',
#  'x7',
#  'y7',
#  'z7',
#  'v7',
#  'x8',
#  'y8',
#  'z8',
#  'v8',
#  'x9',
#  'y9',
#  'z9',
#  'v9',
#  'x10',
#  'y10',
#  'z10',
#  'v10',
#  'x11',
#  'y11',
#  'z11',
#  'v11',
#  'x12',
#  'y12',
#  'z12',
#  'v12',
#  'x13',
#  'y13',
#  'z13',
#  'v13',
#  'x14',
#  'y14',
#  'z14',
#  'v14',
#  'x15',
#  'y15',
#  'z15',
#  'v15',
#  'x16',
#  'y16',
#  'z16',
#  'v16',
#  'x17',
#  'y17',
#  'z17',
#  'v17',
#  'x18',
#  'y18',
#  'z18',
#  'v18',
#  'x19',
#  'y19',
#  'z19',
#  'v19',
#  'x20',
#  'y20',
#  'z20',
#  'v20',
#  'x21',
#  'y21',
#  'z21',
#  'v21',
#  'x22',
#  'y22',
#  'z22',
#  'v22',
#  'x23',
#  'y23',
#  'z23',
#  'v23',
#  'x24',
#  'y24',
#  'z24',
#  'v24',
#  'x25',
#  'y25',
#  'z25',
#  'v25',
#  'x26',
#  'y26',
#  'z26',
#  'v26',
#  'x27',
#  'y27',
#  'z27',
#  'v27',
#  'x28',
#  'y28',
#  'z28',
#  'v28',
#  'x29',
#  'y29',
#  'z29',
#  'v29',
#  'x30',
#  'y30',
#  'z30',
#  'v30',
#  'x31',
#  'y31',
#  'z31',
#  'v31',
#  'x32',
#  'y32',
#  'z32',
#  'v32',
#  'x33',
#  'y33',
#  'z33',
#  'v33',
#  'x34',
#  'y34',
#  'z34',
#  'v34',
#  'x35',
#  'y35',
#  'z35',
#  'v35',
#  'x36',
#  'y36',
#  'z36',
#  'v36',
#  'x37',
#  'y37',
#  'z37',
#  'v37',
#  'x38',
#  'y38',
#  'z38',
#  'v38',
#  'x39',
#  'y39',
#  'z39',
#  'v39',
#  'x40',
#  'y40',
#  'z40',
#  'v40',
#  'x41',
#  'y41',
#  'z41',
#  'v41',
#  'x42',
#  'y42',
#  'z42',
#  'v42',
#  'x43',
#  'y43',
#  'z43',
#  'v43',
#  'x44',
#  'y44',
#  'z44',
#  'v44',
#  'x45',
#  'y45',
#  'z45',
#  'v45',
#  'x46',
#  'y46',
#  'z46',
#  'v46',
#  'x47',
#  'y47',
#  'z47',
#  'v47',
#  'x48',
#  'y48',
#  'z48',
#  'v48',
#  'x49',
#  'y49',
#  'z49',
#  'v49',
#  'x50',
#  'y50',
#  'z50',
#  'v50',
#  'x51',
#  'y51',
#  'z51',
#  'v51',
#  'x52',
#  'y52',
#  'z52',
#  'v52',
#  'x53',
#  'y53',
#  'z53',
#  'v53',
#  'x54',
#  'y54',
#  'z54',
#  'v54',
#  'x55',
#  'y55',
#  'z55',
#  'v55',
#  'x56',
#  'y56',
#  'z56',
#  'v56',
#  'x57',
#  'y57',
#  'z57',
#  'v57',
#  'x58',
#  'y58',
#  'z58',
#  'v58',
#  'x59',
#  'y59',
#  'z59',
#  'v59',
#  'x60',
#  'y60',
#  'z60',
#  'v60',
#  'x61',
#  'y61',
#  'z61',
#  'v61',
#  'x62',
#  'y62',
#  'z62',
#  'v62',
#  'x63',
#  'y63',
#  'z63',
#  'v63',
#  'x64',
#  'y64',
#  'z64',
#  'v64',
#  'x65',
#  'y65',
#  'z65',
#  'v65',
#  'x66',
#  'y66',
#  'z66',
#  'v66',
#  'x67',
#  'y67',
#  'z67',
#  'v67',
#  'x68',
#  'y68',
#  'z68',
#  'v68',
#  'x69',
#  'y69',
#  'z69',
#  'v69',
#  'x70',
#  'y70',
#  'z70',
#  'v70',
#  'x71',
#  'y71',
#  'z71',
#  'v71',
#  'x72',
#  'y72',
#  'z72',
#  'v72',
#  'x73',
#  'y73',
#  'z73',
#  'v73',
#  'x74',
#  'y74',
#  'z74',
#  'v74',
#  'x75',
#  'y75',
#  'z75',
#  'v75',
#  'x76',
#  'y76',
#  'z76',
#  'v76',
#  'x77',
#  'y77',
#  'z77',
#  'v77',
#  'x78',
#  'y78',
#  'z78',
#  'v78',
#  'x79',
#  'y79',
#  'z79',
#  'v79',
#  'x80',
#  'y80',
#  'z80',
#  'v80',
#  'x81',
#  'y81',
#  'z81',
#  'v81',
#  'x82',
#  'y82',
#  'z82',
#  'v82',
#  'x83',
#  'y83',
#  'z83',
#  'v83',
#  'x84',
#  'y84',
#  'z84',
#  'v84',
#  'x85',
#  'y85',
#  'z85',
#  'v85',
#  'x86',
#  'y86',
#  'z86',
#  'v86',
#  'x87',
#  'y87',
#  'z87',
#  'v87',
#  'x88',
#  'y88',
#  'z88',
#  'v88',
#  'x89',
#  'y89',
#  'z89',
#  'v89',
#  'x90',
#  'y90',
#  'z90',
#  'v90',
#  'x91',
#  'y91',
#  'z91',
#  'v91',
#  'x92',
#  'y92',
#  'z92',
#  'v92',
#  'x93',
#  'y93',
#  'z93',
#  'v93',
#  'x94',
#  'y94',
#  'z94',
#  'v94',
#  'x95',
#  'y95',
#  'z95',
#  'v95',
#  'x96',
#  'y96',
#  'z96',
#  'v96',
#  'x97',
#  'y97',
#  'z97',
#  'v97',
#  'x98',
#  'y98',
#  'z98',
#  'v98',
#  'x99',
#  'y99',
#  'z99',
#  'v99',
#  'x100',
#  'y100',
#  'z100',
#  'v100',
#  'x101',
#  'y101',
#  'z101',
#  'v101',
#  'x102',
#  'y102',
#  'z102',
#  'v102',
#  'x103',
#  'y103',
#  'z103',
#  'v103',
#  'x104',
#  'y104',
#  'z104',
#  'v104',
#  'x105',
#  'y105',
#  'z105',
#  'v105',
#  'x106',
#  'y106',
#  'z106',
#  'v106',
#  'x107',
#  'y107',
#  'z107',
#  'v107',
#  'x108',
#  'y108',
#  'z108',
#  'v108',
#  'x109',
#  'y109',
#  'z109',
#  'v109',
#  'x110',
#  'y110',
#  'z110',
#  'v110',
#  'x111',
#  'y111',
#  'z111',
#  'v111',
#  'x112',
#  'y112',
#  'z112',
#  'v112',
#  'x113',
#  'y113',
#  'z113',
#  'v113',
#  'x114',
#  'y114',
#  'z114',
#  'v114',
#  'x115',
#  'y115',
#  'z115',
#  'v115',
#  'x116',
#  'y116',
#  'z116',
#  'v116',
#  'x117',
#  'y117',
#  'z117',
#  'v117',
#  'x118',
#  'y118',
#  'z118',
#  'v118',
#  'x119',
#  'y119',
#  'z119',
#  'v119',
#  'x120',
#  'y120',
#  'z120',
#  'v120',
#  'x121',
#  'y121',
#  'z121',
#  'v121',
#  'x122',
#  'y122',
#  'z122',
#  'v122',
#  'x123',
#  'y123',
#  'z123',
#  'v123',
#  'x124',
#  'y124',
#  'z124',
#  'v124',
#  'x125',
#  'y125',
#  'z125',
#  'v125',
#  'x126',
#  'y126',
#  'z126',
#  'v126',
#  'x127',
#  'y127',
#  'z127',
#  'v127',
#  'x128',
#  'y128',
#  'z128',
#  'v128',
#  'x129',
#  'y129',
#  'z129',
#  'v129',
#  'x130',
#  'y130',
#  'z130',
#  'v130',
#  'x131',
#  'y131',
#  'z131',
#  'v131',
#  'x132',
#  'y132',
#  'z132',
#  'v132',
#  'x133',
#  'y133',
#  'z133',
#  'v133',
#  'x134',
#  'y134',
#  'z134',
#  'v134',
#  'x135',
#  'y135',
#  'z135',
#  'v135',
#  'x136',
#  'y136',
#  'z136',
#  'v136',
#  'x137',
#  'y137',
#  'z137',
#  'v137',
#  'x138',
#  'y138',
#  'z138',
#  'v138',
#  'x139',
#  'y139',
#  'z139',
#  'v139',
#  'x140',
#  'y140',
#  'z140',
#  'v140',
#  'x141',
#  'y141',
#  'z141',
#  'v141',
#  'x142',
#  'y142',
#  'z142',
#  'v142',
#  'x143',
#  'y143',
#  'z143',
#  'v143',
#  'x144',
#  'y144',
#  'z144',
#  'v144',
#  'x145',
#  'y145',
#  'z145',
#  'v145',
#  'x146',
#  'y146',
#  'z146',
#  'v146',
#  'x147',
#  'y147',
#  'z147',
#  'v147',
#  'x148',
#  'y148',
#  'z148',
#  'v148',
#  'x149',
#  'y149',
#  'z149',
#  'v149',
#  'x150',
#  'y150',
#  'z150',
#  'v150',
#  'x151',
#  'y151',
#  'z151',
#  'v151',
#  'x152',
#  'y152',
#  'z152',
#  'v152',
#  'x153',
#  'y153',
#  'z153',
#  'v153',
#  'x154',
#  'y154',
#  'z154',
#  'v154',
#  'x155',
#  'y155',
#  'z155',
#  'v155',
#  'x156',
#  'y156',
#  'z156',
#  'v156',
#  'x157',
#  'y157',
#  'z157',
#  'v157',
#  'x158',
#  'y158',
#  'z158',
#  'v158',
#  'x159',
#  'y159',
#  'z159',
#  'v159',
#  'x160',
#  'y160',
#  'z160',
#  'v160',
#  'x161',
#  'y161',
#  'z161',
#  'v161',
#  'x162',
#  'y162',
#  'z162',
#  'v162',
#  'x163',
#  'y163',
#  'z163',
#  'v163',
#  'x164',
#  'y164',
#  'z164',
#  'v164',
#  'x165',
#  'y165',
#  'z165',
#  'v165',
#  'x166',
#  'y166',
#  'z166',
#  'v166',
#  'x167',
#  'y167',
#  'z167',
#  'v167',
#  'x168',
#  'y168',
#  'z168',
#  'v168',
#  'x169',
#  'y169',
#  'z169',
#  'v169',
#  'x170',
#  'y170',
#  'z170',
#  'v170',
#  'x171',
#  'y171',
#  'z171',
#  'v171',
#  'x172',
#  'y172',
#  'z172',
#  'v172',
#  'x173',
#  'y173',
#  'z173',
#  'v173',
#  'x174',
#  'y174',
#  'z174',
#  'v174',
#  'x175',
#  'y175',
#  'z175',
#  'v175',
#  'x176',
#  'y176',
#  'z176',
#  'v176',
#  'x177',
#  'y177',
#  'z177',
#  'v177',
#  'x178',
#  'y178',
#  'z178',
#  'v178',
#  'x179',
#  'y179',
#  'z179',
#  'v179',
#  'x180',
#  'y180',
#  'z180',
#  'v180',
#  'x181',
#  'y181',
#  'z181',
#  'v181',
#  'x182',
#  'y182',
#  'z182',
#  'v182',
#  'x183',
#  'y183',
#  'z183',
#  'v183',
#  'x184',
#  'y184',
#  'z184',
#  'v184',
#  'x185',
#  'y185',
#  'z185',
#  'v185',
#  'x186',
#  'y186',
#  'z186',
#  'v186',
#  'x187',
#  'y187',
#  'z187',
#  'v187',
#  'x188',
#  'y188',
#  'z188',
#  'v188',
#  'x189',
#  'y189',
#  'z189',
#  'v189',
#  'x190',
#  'y190',
#  'z190',
#  'v190',
#  'x191',
#  'y191',
#  'z191',
#  'v191',
#  'x192',
#  'y192',
#  'z192',
#  'v192',
#  'x193',
#  'y193',
#  'z193',
#  'v193',
#  'x194',
#  'y194',
#  'z194',
#  'v194',
#  'x195',
#  'y195',
#  'z195',
#  'v195',
#  'x196',
#  'y196',
#  'z196',
#  'v196',
#  'x197',
#  'y197',
#  'z197',
#  'v197',
#  'x198',
#  'y198',
#  'z198',
#  'v198',
#  'x199',
#  'y199',
#  'z199',
#  'v199',
#  'x200',
#  'y200',
#  'z200',
#  'v200',
#  'x201',
#  'y201',
#  'z201',
#  'v201',
#  'x202',
#  'y202',
#  'z202',
#  'v202',
#  'x203',
#  'y203',
#  'z203',
#  'v203',
#  'x204',
#  'y204',
#  'z204',
#  'v204',
#  'x205',
#  'y205',
#  'z205',
#  'v205',
#  'x206',
#  'y206',
#  'z206',
#  'v206',
#  'x207',
#  'y207',
#  'z207',
#  'v207',
#  'x208',
#  'y208',
#  'z208',
#  'v208',
#  'x209',
#  'y209',
#  'z209',
#  'v209',
#  'x210',
#  'y210',
#  'z210',
#  'v210',
#  'x211',
#  'y211',
#  'z211',
#  'v211',
#  'x212',
#  'y212',
#  'z212',
#  'v212',
#  'x213',
#  'y213',
#  'z213',
#  'v213',
#  'x214',
#  'y214',
#  'z214',
#  'v214',
#  'x215',
#  'y215',
#  'z215',
#  'v215',
#  'x216',
#  'y216',
#  'z216',
#  'v216',
#  'x217',
#  'y217',
#  'z217',
#  'v217',
#  'x218',
#  'y218',
#  'z218',
#  'v218',
#  'x219',
#  'y219',
#  'z219',
#  'v219',
#  'x220',
#  'y220',
#  'z220',
#  'v220',
#  'x221',
#  'y221',
#  'z221',
#  'v221',
#  'x222',
#  'y222',
#  'z222',
#  'v222',
#  'x223',
#  'y223',
#  'z223',
#  'v223',
#  'x224',
#  'y224',
#  'z224',
#  'v224',
#  'x225',
#  'y225',
#  'z225',
#  'v225',
#  'x226',
#  'y226',
#  'z226',
#  'v226',
#  'x227',
#  'y227',
#  'z227',
#  'v227',
#  'x228',
#  'y228',
#  'z228',
#  'v228',
#  'x229',
#  'y229',
#  'z229',
#  'v229',
#  'x230',
#  'y230',
#  'z230',
#  'v230',
#  'x231',
#  'y231',
#  'z231',
#  'v231',
#  'x232',
#  'y232',
#  'z232',
#  'v232',
#  'x233',
#  'y233',
#  'z233',
#  'v233',
#  'x234',
#  'y234',
#  'z234',
#  'v234',
#  'x235',
#  'y235',
#  'z235',
#  'v235',
#  'x236',
#  'y236',
#  'z236',
#  'v236',
#  'x237',
#  'y237',
#  'z237',
#  'v237',
#  'x238',
#  'y238',
#  'z238',
#  'v238',
#  'x239',
#  'y239',
#  'z239',
#  'v239',
#  'x240',
#  'y240',
#  'z240',
#  'v240',
#  'x241',
#  'y241',
#  'z241',
#  'v241',
#  'x242',
#  'y242',
#  'z242',
#  'v242',
#  'x243',
#  'y243',
#  'z243',
#  'v243',
#  'x244',
#  'y244',
#  'z244',
#  'v244',
#  'x245',
#  'y245',
#  'z245',
#  'v245',
#  'x246',
#  'y246',
#  'z246',
#  'v246',
#  'x247',
#  'y247',
#  'z247',
#  'v247',
#  'x248',
#  'y248',
#  'z248',
#  'v248',
#  'x249',
#  'y249',
#  'z249',
#  'v249',
#  'x250',
#  'y250',
#  'z250',
#  ...]

# %%
with open('coords.csv', mode='w', newline='') as f:
    csv_writer = csv.writer(f, delimiter=',', quotechar='"', quoting=csv.QUOTE_MINIMAL)
    csv_writer.writerow(landmarks)

# %%
temp_intensity = 1
class_name = "Happy_"+str(temp_intensity)
gap_time = 2

# %%
cap = cv2.VideoCapture(2)
temp_time = time.time()
# Initiate holistic model
with mp_holistic.Holistic(min_detection_confidence=0.5, min_tracking_confidence=0.5) as holistic:
    
    while cap.isOpened():
        ret, frame = cap.read()
        
        # Recolor Feed
        image = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
        image.flags.writeable = False        
        
        # Make Detections
        results = holistic.process(image)
        # print(results.face_landmarks)
        
        # face_landmarks, pose_landmarks, left_hand_landmarks, right_hand_landmarks
        
        # Recolor image back to BGR for rendering
        image.flags.writeable = True   
        image = cv2.cvtColor(image, cv2.COLOR_RGB2BGR)
        
        # 1. Draw face landmarks
        mp_drawing.draw_landmarks(image, results.face_landmarks, mp_holistic.FACEMESH_TESSELATION, 
                                 mp_drawing.DrawingSpec(color=(80,110,10), thickness=1, circle_radius=1),
                                 mp_drawing.DrawingSpec(color=(80,256,121), thickness=1, circle_radius=1)
                                 )
        
        # 2. Right hand
        mp_drawing.draw_landmarks(image, results.right_hand_landmarks, mp_holistic.HAND_CONNECTIONS, 
                                 mp_drawing.DrawingSpec(color=(80,22,10), thickness=2, circle_radius=4),
                                 mp_drawing.DrawingSpec(color=(80,44,121), thickness=2, circle_radius=2)
                                 )

        # 3. Left Hand
        mp_drawing.draw_landmarks(image, results.left_hand_landmarks, mp_holistic.HAND_CONNECTIONS, 
                                 mp_drawing.DrawingSpec(color=(121,22,76), thickness=2, circle_radius=4),
                                 mp_drawing.DrawingSpec(color=(121,44,250), thickness=2, circle_radius=2)
                                 )

        # 4. Pose Detections
        mp_drawing.draw_landmarks(image, results.pose_landmarks, mp_holistic.POSE_CONNECTIONS, 
                                 mp_drawing.DrawingSpec(color=(245,117,66), thickness=2, circle_radius=4),
                                 mp_drawing.DrawingSpec(color=(245,66,230), thickness=2, circle_radius=2)
                                 )
        # Export coordinates
        try:
            # Extract Pose landmarks
            pose = results.pose_landmarks.landmark
            pose_row = list(np.array([[landmark.x, landmark.y, landmark.z, landmark.visibility] for landmark in pose]).flatten())
            
            # Extract Face landmarks
            face = results.face_landmarks.landmark
            face_row = list(np.array([[landmark.x, landmark.y, landmark.z, landmark.visibility] for landmark in face]).flatten())
            
            # Concate rows
            row = pose_row+face_row
            
            # Append class name 
            row.insert(0, class_name)
            
            # Export to CSV
            with open('coords.csv', mode='a', newline='') as f:
                csv_writer = csv.writer(f, delimiter=',', quotechar='"', quoting=csv.QUOTE_MINIMAL)
                csv_writer.writerow(row) 
            
        except:
            pass
                        
        cv2.imshow('Raw Webcam Feed', image)
        if (time.time() >= temp_time+gap_time):
            filename = f"{class_name}.jpg"
            cv2.imwrite(filename, image)
            break
        if cv2.waitKey(10) & 0xFF == ord('q'):
            break

cap.release()
cv2.destroyAllWindows()

# %% [markdown]
# # 3. Train Custom Model Using Scikit Learn

# %% [markdown]
# ## 3.1 Read in Collected Data and Process

# %%
import pandas as pd
from sklearn.model_selection import train_test_split

# %%
df = pd.read_csv('coords.csv')

# %%
df.head()
# Out:
#   class_intensity        x1        y1        z1        v1        x2        y2  \
# 0         Anger_0  0.577899  0.161636 -0.521069  0.999299  0.595118  0.126249
# 1         Anger_0  0.572582  0.162493 -0.478620  0.999191  0.590330  0.127199
# 2         Anger_0  0.571242  0.163071 -0.463663  0.999086  0.589101  0.127825
# 3         Anger_0  0.569826  0.163346 -0.471091  0.999031  0.587917  0.128162
# 4         Anger_0  0.569511  0.163737 -0.477443  0.999006  0.587697  0.129013
#
#          z2        v2        x3  ...      z499  v499      x500      y500  \
# 0 -0.483450  0.997336  0.605116  ...  0.003463   0.0  0.611896  0.134555
# 1 -0.441128  0.996999  0.601711  ...  0.004310   0.0  0.610680  0.135882
# 2 -0.424601  0.996615  0.600875  ...  0.003784   0.0  0.609331  0.136746
# 3 -0.431954  0.996404  0.600000  ...  0.003450   0.0  0.609309  0.136437
# 4 -0.438676  0.996312  0.599825  ...  0.003632   0.0  0.608662  0.137375
#
#        z500  v500      x501      y501      z501  v501
# 0  0.014429   0.0  0.615214  0.131466  0.014894   0.0
# 1  0.015622   0.0  0.614071  0.132871  0.016067   0.0
# 2  0.014701   0.0  0.612811  0.133523  0.015145   0.0
# 3  0.014265   0.0  0.612784  0.133243  0.014675   0.0
# 4  0.014187   0.0  0.612136  0.134219  0.014597   0.0
#
# [5 rows x 2005 columns]

# %%
df.tail()
# Out:
#     class_intensity        x1        y1        z1        v1        x2  \
# 286         Happy_1  0.584635  0.222991 -0.537149  0.999770  0.606831
# 287         Happy_1  0.584587  0.222532 -0.521882  0.999753  0.606921
# 288         Happy_1  0.584746  0.222819 -0.502313  0.999737  0.607654
# 289         Happy_1  0.584788  0.223826 -0.496675  0.999724  0.607754
# 290         Happy_1  0.585087  0.225218 -0.649466  0.999324  0.609081
#
#            y2        z2        v2        x3  ...      z499  v499      x500  \
# 286  0.183224 -0.518947  0.999608  0.620559  ... -0.006629   0.0  0.630437
# 287  0.182883 -0.502282  0.999583  0.620587  ... -0.006826   0.0  0.631766
# 288  0.183220 -0.483831  0.999553  0.621117  ... -0.006944   0.0  0.633348
# 289  0.184300 -0.478429  0.999529  0.621244  ... -0.007617   0.0  0.634298
# 290  0.185630 -0.617710  0.998172  0.622434  ... -0.005817   0.0  0.635303
#
#          y500      z500  v500      x501      y501      z501  v501
# 286  0.185558  0.003806   0.0  0.634086  0.182956  0.003927   0.0
# 287  0.186838  0.003782   0.0  0.635410  0.184021  0.003933   0.0
# 288  0.189899  0.003765   0.0  0.637028  0.187218  0.003896   0.0
# 289  0.191065  0.002959   0.0  0.637952  0.188456  0.003053   0.0
# 290  0.190919  0.005275   0.0  0.639203  0.188086  0.005354   0.0
#
# [5 rows x 2005 columns]

# %%
df[df['class_intensity']=='Sad_1']
# Out:
#     class_intensity        x1        y1        z1        v1        x2  \
# 206           Sad_1  0.536401  0.290521 -0.829387  0.999616  0.542997
# 207           Sad_1  0.536214  0.291227 -0.854516  0.999198  0.542668
# 208           Sad_1  0.538787  0.288739 -0.883224  0.999098  0.544984
# 209           Sad_1  0.537959  0.287993 -0.821054  0.999121  0.544077
# 210           Sad_1  0.536220  0.287685 -0.747416  0.999106  0.542385
# 211           Sad_1  0.534729  0.287389 -0.710362  0.998877  0.540976
# 212           Sad_1  0.534362  0.287019 -0.710900  0.998717  0.540817
# 213           Sad_1  0.533177  0.286884 -0.573425  0.998009  0.539152
# 214           Sad_1  0.531943  0.284833 -0.450029  0.997953  0.538197
# 215           Sad_1  0.530621  0.282891 -0.436342  0.997905  0.536991
# 216           Sad_1  0.526781  0.279199 -0.426160  0.997938  0.533790
# 217           Sad_1  0.523168  0.277625 -0.390051  0.997917  0.530318
# 218           Sad_1  0.521185  0.274323 -0.374987  0.998009  0.528601
# 219           Sad_1  0.520308  0.272579 -0.422248  0.998047  0.528175
# 220           Sad_1  0.518432  0.270742 -0.392912  0.998151  0.526783
#
#            y2        z2        v2        x3  ...      z499  v499      x500  \
# 206  0.246670 -0.853050  0.999345  0.555026  ... -0.016209   0.0  0.558117
# 207  0.246860 -0.878249  0.998809  0.554478  ... -0.016323   0.0  0.554255
# 208  0.242076 -0.898426  0.998667  0.556595  ... -0.016674   0.0  0.554102
# 209  0.241980 -0.836297  0.998713  0.555537  ... -0.016278   0.0  0.557574
# 210  0.241922 -0.775586  0.998696  0.553865  ... -0.015912   0.0  0.554514
# 211  0.241924 -0.744482  0.998386  0.552455  ... -0.016245   0.0  0.555881
# 212  0.241505 -0.741909  0.998137  0.552286  ... -0.016064   0.0  0.556365
# 213  0.241473 -0.618811  0.996934  0.550337  ... -0.015388   0.0  0.556441
# 214  0.239034 -0.491091  0.996792  0.549430  ... -0.015502   0.0  0.554912
# 215  0.237013 -0.473728  0.996649  0.548284  ... -0.015767   0.0  0.553800
# 216  0.233417 -0.468783  0.996669  0.544690  ... -0.014060   0.0  0.547984
# 217  0.232195 -0.434675  0.996606  0.540981  ... -0.015455   0.0  0.547469
# 218  0.228544 -0.417438  0.996737  0.539235  ... -0.014538   0.0  0.545291
# 219  0.226742 -0.461461  0.996805  0.538914  ... -0.014228   0.0  0.543543
# 220  0.224884 -0.432774  0.996985  0.537760  ... -0.014764   0.0  0.541915
#
#          y500      z500  v500      x501      y501      z501  v501
# 206  0.239867 -0.032037   0.0  0.560437  0.233027 -0.034337   0.0
# 207  0.237607 -0.033920   0.0  0.556112  0.231452 -0.036212   0.0
# 208  0.237603 -0.034627   0.0  0.556013  0.231065 -0.036905   0.0
# 209  0.234611 -0.032411   0.0  0.559932  0.228357 -0.034524   0.0
# 210  0.234238 -0.032833   0.0  0.556755  0.228113 -0.035003   0.0
# 211  0.232649 -0.033765   0.0  0.558129  0.226239 -0.035953   0.0
# 212  0.233467 -0.033684   0.0  0.558607  0.226868 -0.035827   0.0
# 213  0.231482 -0.032045   0.0  0.558628  0.224718 -0.034120   0.0
# 214  0.231706 -0.032830   0.0  0.557203  0.225255 -0.034986   0.0
# 215  0.227202 -0.034266   0.0  0.556145  0.220934 -0.036595   0.0
# 216  0.217483 -0.032138   0.0  0.550396  0.211075 -0.034400   0.0
# 217  0.218805 -0.034387   0.0  0.549969  0.212646 -0.036694   0.0
# 218  0.213322 -0.032411   0.0  0.547724  0.206989 -0.034675   0.0
# 219  0.214307 -0.032746   0.0  0.545952  0.208205 -0.035044   0.0
# 220  0.215292 -0.033444   0.0  0.544276  0.209033 -0.035726   0.0
#
# [15 rows x 2005 columns]

# %%
X = df.drop('class_intensity', axis=1) # features
y = df['class_intensity'] # target value

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=1234)

# %%
y_test
# Out:
# 40        Anger_2
# 100     Disgust_2
# 137        Fear_2
# 232         Sad_2
# 221         Sad_2
# 214         Sad_1
# 69      Disgust_0
# 186       Happy_2
# 104     Disgust_2
# 191       Happy_2
# 253    Surprise_1
# 203         Sad_0
# 153       Happy_0
# 194         Sad_0
# 80      Disgust_1
# 7         Anger_0
# 92      Disgust_2
# 198         Sad_0
# 99      Disgust_2
# 262    Surprise_1
# 102     Disgust_2
# 149       Happy_0
# 6         Anger_0
# 125        Fear_1
# 115        Fear_0
# 206         Sad_1
# 112        Fear_0
# 77      Disgust_1
# 147        Fear_2
# 132        Fear_1
# 74      Disgust_0
# 108        Fear_0
# 268    Surprise_2
# 257    Surprise_1
# 220         Sad_1
# 277       Happy_1
# 31        Anger_1
# 267    Surprise_2
# 212         Sad_1
# 83      Disgust_1
# 282       Happy_1
# 67      Disgust_0
# 71      Disgust_0
# 138        Fear_2
# 244    Surprise_0
# 29        Anger_1
# 227         Sad_2
# 289       Happy_1
# 95      Disgust_2
# 73      Disgust_0
# 269    Surprise_2
# 234    Surprise_0
# 52      Disgust_0
# 124        Fear_1
# 24        Anger_1
# 94      Disgust_2
# 33        Anger_2
# 106        Fear_0
# 127        Fear_1
# Name: class_intensity, dtype: object

# %% [markdown]
# ## 3.2 Train Machine Learning Classification Model

# %%
from sklearn.pipeline import make_pipeline 
from sklearn.preprocessing import StandardScaler 

from sklearn.linear_model import LogisticRegression, RidgeClassifier
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier

# %%
pipelines = {
    'lr':make_pipeline(StandardScaler(), LogisticRegression()),
    'rc':make_pipeline(StandardScaler(), RidgeClassifier()),
    'rf':make_pipeline(StandardScaler(), RandomForestClassifier()),
    'gb':make_pipeline(StandardScaler(), GradientBoostingClassifier()),
}

# %%
fit_models = {}
for algo, pipeline in pipelines.items():
    model = pipeline.fit(X_train, y_train)
    fit_models[algo] = model

# %%
fit_models
# Out:
# {'lr': Pipeline(steps=[('standardscaler', StandardScaler()),
#                  ('logisticregression', LogisticRegression())]),
#  'rc': Pipeline(steps=[('standardscaler', StandardScaler()),
#                  ('ridgeclassifier', RidgeClassifier())]),
#  'rf': Pipeline(steps=[('standardscaler', StandardScaler()),
#                  ('randomforestclassifier', RandomForestClassifier())]),
#  'gb': Pipeline(steps=[('standardscaler', StandardScaler()),
#                  ('gradientboostingclassifier', GradientBoostingClassifier())])}

# %%
fit_models['rc'].predict(X_test)
# Out:
# array(['Anger_2', 'Disgust_2', 'Fear_2', 'Sad_2', 'Sad_2', 'Sad_1',
#        'Disgust_0', 'Happy_2', 'Disgust_2', 'Happy_2', 'Surprise_1',
#        'Sad_0', 'Happy_0', 'Sad_0', 'Disgust_1', 'Anger_0', 'Disgust_2',
#        'Sad_0', 'Disgust_2', 'Surprise_1', 'Disgust_2', 'Happy_0',
#        'Anger_0', 'Fear_1', 'Fear_0', 'Sad_1', 'Fear_0', 'Disgust_1',
#        'Fear_2', 'Fear_1', 'Disgust_0', 'Fear_0', 'Surprise_2',
#        'Surprise_1', 'Sad_1', 'Happy_1', 'Anger_1', 'Surprise_2', 'Sad_1',
#        'Disgust_1', 'Happy_1', 'Disgust_0', 'Disgust_0', 'Fear_2',
#        'Surprise_0', 'Anger_1', 'Sad_2', 'Happy_1', 'Disgust_2',
#        'Disgust_0', 'Surprise_2', 'Surprise_0', 'Disgust_0', 'Fear_1',
#        'Anger_1', 'Disgust_2', 'Anger_2', 'Fear_0', 'Fear_1'],
#       dtype='<U10')

# %% [markdown]
# ## 3.3 Evaluate and Serialize Model

# %%
from sklearn.metrics import accuracy_score # Accuracy metrics 
import pickle

# %%
for algo, model in fit_models.items():
    yhat = model.predict(X_test)
    print(algo, accuracy_score(y_test, yhat))
# Out:
# lr 1.0
# rc 1.0
# rf 1.0
# gb 0.9830508474576272

# %%
fit_models['rf'].predict(X_test)
# Out:
# array(['Anger_2', 'Disgust_2', 'Fear_2', 'Sad_2', 'Sad_2', 'Sad_1',
#        'Disgust_0', 'Happy_2', 'Disgust_2', 'Happy_2', 'Surprise_1',
#        'Sad_0', 'Happy_0', 'Sad_0', 'Disgust_1', 'Anger_0', 'Disgust_2',
#        'Sad_0', 'Disgust_2', 'Surprise_1', 'Disgust_2', 'Happy_0',
#        'Anger_0', 'Fear_1', 'Fear_0', 'Sad_1', 'Fear_0', 'Disgust_1',
#        'Fear_2', 'Fear_1', 'Disgust_0', 'Fear_0', 'Surprise_2',
#        'Surprise_1', 'Sad_1', 'Happy_1', 'Anger_1', 'Surprise_2', 'Sad_1',
#        'Disgust_1', 'Happy_1', 'Disgust_0', 'Disgust_0', 'Fear_2',
#        'Surprise_0', 'Anger_1', 'Sad_2', 'Happy_1', 'Disgust_2',
#        'Disgust_0', 'Surprise_2', 'Surprise_0', 'Disgust_0', 'Fear_1',
#        'Anger_1', 'Disgust_2', 'Anger_2', 'Fear_0', 'Fear_1'],
#       dtype=object)

# %%
y_test
# Out:
# 40        Anger_2
# 100     Disgust_2
# 137        Fear_2
# 232         Sad_2
# 221         Sad_2
# 214         Sad_1
# 69      Disgust_0
# 186       Happy_2
# 104     Disgust_2
# 191       Happy_2
# 253    Surprise_1
# 203         Sad_0
# 153       Happy_0
# 194         Sad_0
# 80      Disgust_1
# 7         Anger_0
# 92      Disgust_2
# 198         Sad_0
# 99      Disgust_2
# 262    Surprise_1
# 102     Disgust_2
# 149       Happy_0
# 6         Anger_0
# 125        Fear_1
# 115        Fear_0
# 206         Sad_1
# 112        Fear_0
# 77      Disgust_1
# 147        Fear_2
# 132        Fear_1
# 74      Disgust_0
# 108        Fear_0
# 268    Surprise_2
# 257    Surprise_1
# 220         Sad_1
# 277       Happy_1
# 31        Anger_1
# 267    Surprise_2
# 212         Sad_1
# 83      Disgust_1
# 282       Happy_1
# 67      Disgust_0
# 71      Disgust_0
# 138        Fear_2
# 244    Surprise_0
# 29        Anger_1
# 227         Sad_2
# 289       Happy_1
# 95      Disgust_2
# 73      Disgust_0
# 269    Surprise_2
# 234    Surprise_0
# 52      Disgust_0
# 124        Fear_1
# 24        Anger_1
# 94      Disgust_2
# 33        Anger_2
# 106        Fear_0
# 127        Fear_1
# Name: class_intensity, dtype: object

# %%
with open('body_language.pkl', 'wb') as f:
    pickle.dump(fit_models['rf'], f)    #we will be dumping random forest model

# %% [markdown]
# # 4. Make Detections with Model

# %%
import pickle
with open('body_language.pkl', 'rb') as f:
    model = pickle.load(f)

# %%
model
# Out:
# Pipeline(steps=[('standardscaler', StandardScaler()),
#                 ('randomforestclassifier', RandomForestClassifier())])

# %%
cap = cv2.VideoCapture(2)
# Initiate holistic model
with mp_holistic.Holistic(min_detection_confidence=0.5, min_tracking_confidence=0.5) as holistic:
    
    while cap.isOpened():
        ret, frame = cap.read()
        
        # Recolor Feed
        image = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
        image.flags.writeable = False        
        
        # Make Detections
        results = holistic.process(image)
        # print(results.face_landmarks)
        
        # face_landmarks, pose_landmarks, left_hand_landmarks, right_hand_landmarks
        
        # Recolor image back to BGR for rendering
        image.flags.writeable = True   
        image = cv2.cvtColor(image, cv2.COLOR_RGB2BGR)
        
        # 1. Draw face landmarks
        mp_drawing.draw_landmarks(image, results.face_landmarks, mp_holistic.FACEMESH_TESSELATION, 
                                 mp_drawing.DrawingSpec(color=(80,110,10), thickness=1, circle_radius=1),
                                 mp_drawing.DrawingSpec(color=(80,256,121), thickness=1, circle_radius=1)
                                 )
        
        # 2. Right hand
        mp_drawing.draw_landmarks(image, results.right_hand_landmarks, mp_holistic.HAND_CONNECTIONS, 
                                 mp_drawing.DrawingSpec(color=(80,22,10), thickness=2, circle_radius=4),
                                 mp_drawing.DrawingSpec(color=(80,44,121), thickness=2, circle_radius=2)
                                 )

        # 3. Left Hand
        mp_drawing.draw_landmarks(image, results.left_hand_landmarks, mp_holistic.HAND_CONNECTIONS, 
                                 mp_drawing.DrawingSpec(color=(121,22,76), thickness=2, circle_radius=4),
                                 mp_drawing.DrawingSpec(color=(121,44,250), thickness=2, circle_radius=2)
                                 )

        # 4. Pose Detections
        mp_drawing.draw_landmarks(image, results.pose_landmarks, mp_holistic.POSE_CONNECTIONS, 
                                 mp_drawing.DrawingSpec(color=(245,117,66), thickness=2, circle_radius=4),
                                 mp_drawing.DrawingSpec(color=(245,66,230), thickness=2, circle_radius=2)
                                 )
        # Export coordinates
        try:
            # Extract Pose landmarks
            pose = results.pose_landmarks.landmark
            pose_row = list(np.array([[landmark.x, landmark.y, landmark.z, landmark.visibility] for landmark in pose]).flatten())
            
            # Extract Face landmarks
            face = results.face_landmarks.landmark
            face_row = list(np.array([[landmark.x, landmark.y, landmark.z, landmark.visibility] for landmark in face]).flatten())
            
            # Concate rows
            row = pose_row+face_row
            
#             # Append class name 
#             row.insert(0, class_name)
            
#             # Export to CSV
#             with open('coords.csv', mode='a', newline='') as f:
#                 csv_writer = csv.writer(f, delimiter=',', quotechar='"', quoting=csv.QUOTE_MINIMAL)
#                 csv_writer.writerow(row) 

            # Make Detections
            X = pd.DataFrame([row])
            body_language_class = model.predict(X)[0]
            body_language_prob = model.predict_proba(X)[0]
            print(body_language_class, body_language_prob)
            
            # Grab ear coords
            coords = tuple(np.multiply(
                            np.array(
                                (results.pose_landmarks.landmark[mp_holistic.PoseLandmark.LEFT_EAR].x, 
                                 results.pose_landmarks.landmark[mp_holistic.PoseLandmark.LEFT_EAR].y))
                        , [640,480]).astype(int))
            
            cv2.rectangle(image, 
                          (coords[0], coords[1]+5), 
                          (coords[0]+len(body_language_class)*20, coords[1]-30), 
                          (245, 117, 16), -1)
            cv2.putText(image, body_language_class, coords, 
                        cv2.FONT_HERSHEY_SIMPLEX, 1, (255, 255, 255), 2, cv2.LINE_AA)
            
            # Get status box
            cv2.rectangle(image, (0,0), (250, 60), (245, 117, 16), -1)
            
            # Display Class
            cv2.putText(image, 'CLASS'
                        , (95,12), cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 0, 0), 1, cv2.LINE_AA)
            cv2.putText(image, body_language_class.split(' ')[0]
                        , (90,40), cv2.FONT_HERSHEY_SIMPLEX, 1, (255, 255, 255), 2, cv2.LINE_AA)
            
            # Display Probability
            cv2.putText(image, 'PROB'
                        , (15,12), cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 0, 0), 1, cv2.LINE_AA)
            cv2.putText(image, str(round(body_language_prob[np.argmax(body_language_prob)],2))
                        , (10,40), cv2.FONT_HERSHEY_SIMPLEX, 1, (255, 255, 255), 2, cv2.LINE_AA)
            
        except:
            pass
                        
        cv2.imshow('Raw Webcam Feed', image)

        if cv2.waitKey(10) & 0xFF == ord('q'):
            break

cap.release()
cv2.destroyAllWindows()
# Out:
# c:\Users\Kartik Gounder\Desktop\Projects\.venv\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Kartik Gounder\Desktop\Projects\.venv\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Kartik Gounder\Desktop\Projects\.venv\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Kartik Gounder\Desktop\Projects\.venv\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Kartik Gounder\Desktop\Projects\.venv\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# Happy_2 [0.   0.01 0.03 0.   0.09 0.   0.   0.01 0.07 0.   0.   0.54 0.   0.
#  0.08 0.01 0.   0.16]
# Happy_2 [0.   0.01 0.01 0.   0.09 0.   0.   0.01 0.07 0.   0.01 0.54 0.   0.
#  0.1  0.02 0.   0.14]
# c:\Users\Kartik Gounder\Desktop\Projects\.venv\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Kartik Gounder\Desktop\Projects\.venv\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Kartik Gounder\Desktop\Projects\.venv\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Kartik Gounder\Desktop\Projects\.venv\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Kartik Gounder\Desktop\Projects\.venv\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# Happy_2 [0.   0.01 0.   0.   0.09 0.   0.   0.01 0.07 0.   0.01 0.53 0.   0.
#  0.12 0.02 0.   0.14]
# Happy_2 [0.   0.01 0.   0.   0.09 0.   0.   0.01 0.07 0.   0.01 0.53 0.   0.
#  0.12 0.02 0.   0.14]
# Happy_2 [0.   0.01 0.   0.   0.09 0.   0.   0.01 0.07 0.   0.01 0.53 0.   0.
#  0.12 0.02 0.   0.14]
# c:\Users\Kartik Gounder\Desktop\Projects\.venv\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Kartik Gounder\Desktop\Projects\.venv\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Kartik Gounder\Desktop\Projects\.venv\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Kartik Gounder\Desktop\Projects\.venv\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# Happy_2 [0.   0.01 0.01 0.   0.09 0.   0.   0.01 0.07 0.   0.01 0.54 0.   0.
#  0.1  0.02 0.   0.14]
# Happy_2 [0.   0.01 0.01 0.   0.1  0.   0.   0.01 0.07 0.   0.01 0.53 0.   0.
#  0.1  0.02 0.   0.14]
# c:\Users\Kartik Gounder\Desktop\Projects\.venv\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Kartik Gounder\Desktop\Projects\.venv\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Kartik Gounder\Desktop\Projects\.venv\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Kartik Gounder\Desktop\Projects\.venv\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Kartik Gounder\Desktop\Projects\.venv\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Kartik Gounder\Desktop\Projects\.venv\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# Happy_2 [0.   0.01 0.   0.   0.1  0.   0.   0.01 0.09 0.   0.01 0.5  0.   0.
#  0.12 0.02 0.   0.14]
# Happy_2 [0.   0.01 0.   0.01 0.1  0.   0.   0.   0.09 0.   0.01 0.51 0.   0.
#  0.11 0.02 0.   0.14]
# Happy_2 [0.   0.01 0.   0.01 0.1  0.   0.   0.   0.09 0.   0.01 0.51 0.   0.
#  0.11 0.02 0.   0.14]
# c:\Users\Kartik Gounder\Desktop\Projects\.venv\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Kartik Gounder\Desktop\Projects\.venv\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Kartik Gounder\Desktop\Projects\.venv\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Kartik Gounder\Desktop\Projects\.venv\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Kartik Gounder\Desktop\Projects\.venv\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Kartik Gounder\Desktop\Projects\.venv\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# Happy_2 [0.   0.01 0.   0.01 0.1  0.   0.   0.   0.09 0.   0.01 0.51 0.   0.
#  0.11 0.02 0.   0.14]
# Happy_2 [0.   0.01 0.   0.01 0.1  0.   0.   0.   0.09 0.   0.01 0.51 0.   0.
#  0.11 0.02 0.   0.14]
# Happy_2 [0.   0.01 0.   0.01 0.1  0.   0.   0.   0.09 0.   0.01 0.5  0.   0.
#  0.12 0.02 0.   0.14]
# c:\Users\Kartik Gounder\Desktop\Projects\.venv\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Kartik Gounder\Desktop\Projects\.venv\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Kartik Gounder\Desktop\Projects\.venv\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Kartik Gounder\Desktop\Projects\.venv\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Kartik Gounder\Desktop\Projects\.venv\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# Happy_2 [0.   0.01 0.   0.01 0.1  0.   0.   0.   0.09 0.   0.01 0.5  0.   0.
#  0.12 0.02 0.   0.14]
# Happy_2 [0.   0.01 0.   0.01 0.1  0.   0.   0.   0.09 0.   0.01 0.5  0.   0.
#  0.12 0.02 0.   0.14]
# c:\Users\Kartik Gounder\Desktop\Projects\.venv\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Kartik Gounder\Desktop\Projects\.venv\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Kartik Gounder\Desktop\Projects\.venv\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Kartik Gounder\Desktop\Projects\.venv\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Kartik Gounder\Desktop\Projects\.venv\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# Happy_2 [0.   0.01 0.   0.01 0.1  0.   0.   0.   0.09 0.   0.01 0.5  0.   0.
#  0.12 0.02 0.   0.14]
# Happy_2 [0.   0.01 0.   0.01 0.1  0.   0.   0.   0.09 0.   0.01 0.5  0.   0.
#  0.12 0.02 0.   0.14]
# Happy_2 [0.   0.01 0.   0.01 0.1  0.   0.   0.   0.09 0.   0.01 0.5  0.   0.
#  0.12 0.02 0.   0.14]

# %%
tuple(np.multiply(np.array((results.pose_landmarks.landmark[mp_holistic.PoseLandmark.LEFT_EAR].x, 
results.pose_landmarks.landmark[mp_holistic.PoseLandmark.LEFT_EAR].y)), [640,480]).astype(int))
# Out:
# (480, 333)
